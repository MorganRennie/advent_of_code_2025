# %%
import re
input = "C:/Users/MorganAlexanderRenni/Documents/Git Hub/advent_of_code_2025/02_puzzle/input_01.txt"

with open(input,"r") as f:
    string = f.read()

example = "998-1010"

# %%
regex_pattern = (r'\d+-\d*')
left_extract_pattern = (r'^\d+')
right_extract_pattern = (r'\d+$')
input_list = re.findall(regex_pattern,string)

##print(input_list)
sum_of_values = 0


for i, value in enumerate(input_list):
    ##print(f'looking in range {value}')
    values = re.split(r'-', value)
    range_of_values = list(range(int(values[0]), int(values[1])+1))
    for y in range_of_values:
        ##print(y)
        x = str(y)
        repeating = x in (x + x)[1:-1]
        ##print(res)
        if repeating: 
            sum_of_values = sum_of_values + y

print(f'total sum of values= {sum_of_values}')
# Out:
# total sum of values= 21932258645

# %%
regex_pattern = (r'\d+-\d*')
left_extract_pattern = (r'^\d+')
right_extract_pattern = (r'\d+$')
input_list = re.findall(regex_pattern,string)

##print(input_list)
sum_of_values = 0

len(set(x)) == len(x)
for i, value in enumerate(input_list):
    ##print(f'looking in range {value}')
    values = re.split(r'-', value)
    range_of_values = list(range(int(values[0]), int(values[1])+1))
    for y in range_of_values:
        x = str(y)
        ##print(f'for the value {x}')
        length = len(x)
        ##print(f'length = {length}')
        half_length = int(length/2)
        ##print(f'half length = {half_length}')

        first_half = x[:half_length]
        second_half = x[half_length:]

        ##print(f'the number is {x}. this is {length} digits long.')
        ##print(f'the first half of the value is {first_half}, and the second half is {second_half}')

        if first_half == second_half: 
            ##print('these values match')
            sum_of_values = sum_of_values + y
            

print(f'total sum of values= {sum_of_values}')
# Out:
# total sum of values= 19128774598
